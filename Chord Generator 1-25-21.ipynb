# %%
#Version 7: adds chromatic vs. diatonic option. Chromatic option only gives major keys for now.

from pylab import *
from playsound import playsound

#These chord lists tell us which chords we're allowed to travel to from any previous chord.
#For major keys (diatonic):
I = ['ii', 'ii', 'iii', 'IV', 'IV', 'V', 'vi', 'vi', 'vii']
ii = ['V', 'V', 'V', 'vii']
iii = ['ii', 'IV']
IV = ['I', 'ii', 'V']
V = ['I', 'I', 'I', 'vi']
vi = ['ii', 'IV']
vii = ['I', 'I', 'I', 'vi']

#For minor keys (diatonic):
i = ['ii', 'III', 'iv', 'iv', 'V', 'VI', 'VI', 'vii']
iim = ['V', 'V', 'V', 'vii']
III = ['ii', 'iv']
iv = ['i', 'ii', 'V']
Vm = ['i', 'i', 'i', 'VI']
VI = ['ii', 'iv']
viim = ['i', 'i', 'i', 'VI']

#And finally, for chromatic chords in major keys:
Ic = ['ii', 'ii', 'iii', 'IV', 'IV', 'V', 'vi', 'vi', 'vii', 'V/ii', 'V/iii', 'V/V', 'V/vi', 'V/bII', 'V/bIII', 'V/bVI', 'bII', 'III', 'bIII', 'iv', 'VI', 'bVI', 'bVII']
iic = ['V', 'vii', 'V/V', 'bII']
iiic = ['ii', 'IV', 'V/ii', 'V/vi', 'bII', 'iv', 'VI', 'bVI']
IVc = ['I', 'ii', 'V', 'V/ii', 'V/V', 'bII', 'iv']
Vc = ['I', 'I', 'I', 'I', 'vi', 'V/vi']
vic = ['ii', 'IV', 'V/ii', 'V/V', 'bII', 'iv', 'VI', 'bVI']
viic = ['I', 'I', 'I', 'I', 'vi', 'V/vi']
Vofii = ['ii', 'ii', 'V/V', 'bII']
Vofiii = ['iii', 'iii', 'V/vi', 'III', 'bIII']
VofV = ['V']
Vofvi = ['vi', 'vi', 'V/ii', 'VI', 'bVI']
VofbII = ['bII']
VofbIII = ['V/bVI', 'bIII']
VofbVI = ['V/bII', 'bVI']
bII = ['V', 'vii', 'V/V']
IIIc = ['IV', 'iv', 'bIII']
bIII = ['vi']
ivc = ['I', 'ii', 'V', 'vii', 'bII']
VIc = ['bII']
bVI = ['ii', 'V/ii', 'V/V', 'iv']
bVII = ['bII', 'iv', 'bVI', 'bVI', 'bVI']

#Here we translate strings into a different, but still readable data type:
major_numeral_list = {'I': I, 'ii': ii, 'iii': iii, 'IV': IV, 'V': V, 'vi': vi, 'vii': vii}
minor_numeral_list = {'i': i, 'ii': iim, 'III': III, 'iv': iv, 'V': Vm, 'VI': VI, 'vii': viim}
chrom_numeral_list = {'I': Ic, 'ii': iic, 'iii': iiic, 'IV': IVc, 'V': Vc, 'vi': vic, 'vii': viic, 
                      'V/ii': Vofii, 'V/iii': Vofiii, 'V/V': VofV, 'V/vi': Vofvi, 'V/bII': VofbII, 'V/bIII': VofbIII, 'V/bVI': VofbVI, 
                      'bII': bII, 'III': IIIc, 'bIII': bIII, 'iv': ivc, 'VI': VIc, 'bVI': bVI, 'bVII': bVII}

#These chord lists tells the generator what lead-sheet chord symbol to print for each roman numeral, depending on key.
#For major keys (diatonic):
major_key_list = {'C': {'I': 'C', 'ii': 'Dm', 'iii': 'Em', 'IV': 'F', 'V': 'G', 'vi': 'Am', 'vii': 'Bdim'}, 
            'Db': {'I': 'Db', 'ii': 'Ebm', 'iii': 'Fm', 'IV': 'Gb', 'V': 'Ab', 'vi': 'Bbm', 'vii': 'Cdim'}, 
            'D': {'I': 'D', 'ii': 'Em', 'iii': 'F#m', 'IV': 'G', 'V': 'A', 'vi': 'Bm', 'vii': 'C#dim'}, 
            'Eb': {'I': 'Eb', 'ii': 'Fm', 'iii': 'Gm', 'IV': 'Ab', 'V': 'Bb', 'vi': 'Cm', 'vii': 'Ddim'}, 
            'E': {'I': 'E', 'ii': 'F#m', 'iii': 'G#m', 'IV': 'A', 'V': 'B', 'vi': 'C#m', 'vii': 'D#dim'}, 
            'F': {'I': 'F', 'ii': 'Gm', 'iii': 'Am', 'IV': 'Bb', 'V': 'C', 'vi': 'Dm', 'vii': 'Edim'}, 
            'F#': {'I': 'F#', 'ii': 'G#m', 'iii': 'A#m', 'IV': 'B', 'V': 'C#', 'vi': 'D#m', 'vii': 'E#dim'}, 
            'G': {'I': 'G', 'ii': 'Am', 'iii': 'Bm', 'IV': 'C', 'V': 'D', 'vi': 'Em', 'vii': 'F#dim'}, 
            'Ab': {'I': 'Ab', 'ii': 'Bbm', 'iii': 'Cm', 'IV': 'Db', 'V': 'Eb', 'vi': 'Fm', 'vii': 'Gdim'}, 
            'A': {'I': 'A', 'ii': 'Bm', 'iii': 'C#m', 'IV': 'D', 'V': 'E', 'vi': 'F#m', 'vii': 'G#dim'}, 
            'Bb': {'I': 'Bb', 'ii': 'Cm', 'iii': 'Dm', 'IV': 'Eb', 'V': 'F', 'vi': 'Gm', 'vii': 'Adim'}, 
            'B': {'I': 'B', 'ii': 'C#m', 'iii': 'D#m', 'IV': 'E', 'V': 'F#', 'vi': 'G#m', 'vii': 'A#dim'}}

#For minor keys:
minor_key_list = {'C': {'i': 'Cm', 'ii': 'Ddim', 'III': 'Eb', 'iv': 'Fm', 'V': 'G', 'VI': 'Ab', 'vii': 'Bdim'}, 
            'Db': {'i': 'Dbm', 'ii': 'Ebdim', 'III': 'Fb', 'iv': 'Gbm', 'V': 'Ab', 'VI': 'Bbb', 'vii': 'Cdim'}, 
            'D': {'i': 'Dm', 'ii': 'Edim', 'III': 'F', 'iv': 'Gm', 'V': 'A', 'VI': 'Bb', 'vii': 'C#dim'}, 
            'Eb': {'i': 'Ebm', 'ii': 'Fdim', 'III': 'Gb', 'iv': 'Abm', 'V': 'Bb', 'VI': 'Cb', 'vii': 'Ddim'}, 
            'E': {'i': 'Em', 'ii': 'F#dim', 'III': 'G', 'iv': 'Am', 'V': 'B', 'VI': 'C', 'vii': 'D#dim'}, 
            'F': {'i': 'Fm', 'ii': 'Gdim', 'III': 'Ab', 'iv': 'Bbm', 'V': 'C', 'VI': 'Db', 'vii': 'Edim'}, 
            'F#': {'i': 'F#m', 'ii': 'G#dim', 'III': 'A', 'iv': 'Bm', 'V': 'C#', 'VI': 'D', 'vii': 'E#dim'}, 
            'G': {'i': 'Gm', 'ii': 'Adim', 'III': 'Bb', 'iv': 'Cm', 'V': 'D', 'VI': 'Eb', 'vii': 'F#dim'}, 
            'Ab': {'i': 'Abm', 'ii': 'Bbdim', 'III': 'Cb', 'iv': 'Dbm', 'V': 'Eb', 'VI': 'Fb', 'vii': 'Gdim'}, 
            'A': {'i': 'Am', 'ii': 'Bdim', 'III': 'C', 'iv': 'Dm', 'V': 'E', 'VI': 'F', 'vii': 'G#dim'}, 
            'Bb': {'i': 'Bbm', 'ii': 'Cdim', 'III': 'Db', 'iv': 'Ebm', 'V': 'F', 'VI': 'Gb', 'vii': 'Adim'}, 
            'B': {'i': 'Bm', 'ii': 'C#dim', 'III': 'D', 'iv': 'Em', 'V': 'F#', 'VI': 'G', 'vii': 'A#dim'}}

#And finally, for chromatic chords in major keys:
chrom_key_list = {'C' : {'I': 'C', 'ii': 'Dm', 'iii': 'Em', 'IV': 'F', 'V': 'G', 'vi': 'Am', 'vii': 'Bdim', 
                       'V/ii': 'A', 'V/iii': 'B', 'V/V': 'D', 'V/vi': 'E', 'V/bII': 'Ab', 'V/bIII': 'Eb', 'V/bVI': 'Eb', 
                      'bII': 'Db', 'III': 'E', 'bIII': 'Ab', 'iv': 'Fm', 'VI': 'A', 'bVI': 'Ab', 'bVII': 'Bb'},
                 'Db' : {'I': 'Db', 'ii': 'Ebm', 'iii': 'Fm', 'IV': 'Gb', 'V': 'Ab', 'vi': 'Bbm', 'vii': 'Cdim', 
                       'V/ii': 'Bb', 'V/iii': 'C', 'V/V': 'Eb', 'V/vi': 'F', 'V/bII': 'Anat', 'V/bIII': 'Bnat', 'V/bVI': 'Enat', 
                      'bII': 'Dnat', 'III': 'F', 'bIII': 'Enat', 'iv': 'Gbm', 'VI': 'Bb', 'bVI': 'Anat', 'bVII': 'Bnat'}, 
                 'D' : {'I': 'D', 'ii': 'Em', 'iii': 'F#m', 'IV': 'G', 'V': 'A', 'vi': 'Bm', 'vii': 'C#dim', 
                       'V/ii': 'B', 'V/iii': 'C#', 'V/V': 'E', 'V/vi': 'F#', 'V/bII': 'Bb', 'V/bIII': 'Cnat', 'V/bVI': 'Fnat', 
                      'bII': 'Eb', 'III': 'F#', 'bIII': 'Fnat', 'iv': 'Gm', 'VI': 'B', 'bVI': 'Bb', 'bVII': 'Cnat'},
                 'Eb' : {'I': 'Eb', 'ii': 'Fm', 'iii': 'Gm', 'IV': 'Ab', 'V': 'Bb', 'vi': 'Cm', 'vii': 'Ddim', 
                       'V/ii': 'C', 'V/iii': 'D', 'V/V': 'F', 'V/vi': 'G', 'V/bII': 'Bnat', 'V/bIII': 'Db', 'V/bVI': 'Gb', 
                      'bII': 'Enat', 'III': 'G', 'bIII': 'Gb', 'iv': 'Abm', 'VI': 'C', 'bVI': 'Bnat', 'bVII': 'Db'},
                 'E' : {'I': 'E', 'ii': 'F#m', 'iii': 'G#m', 'IV': 'A', 'V': 'B', 'vi': 'C#m', 'vii': 'D#dim', 
                       'V/ii': 'C#', 'V/iii': 'D#', 'V/V': 'F#', 'V/vi': 'G#', 'V/bII': 'Cnat', 'V/bIII': 'Dnat', 'V/bVI': 'Gnat', 
                      'bII': 'Fnat', 'III': 'G#', 'bIII': 'Gnat', 'iv': 'Am', 'VI': 'C#', 'bVI': 'Cnat', 'bVII': 'Dnat'},
                 'F' : {'I': 'F', 'ii': 'Gm', 'iii': 'Am', 'IV': 'Bb', 'V': 'C', 'vi': 'Dm', 'vii': 'Edim', 
                       'V/ii': 'D', 'V/iii': 'E', 'V/V': 'G', 'V/vi': 'A', 'V/bII': 'Db', 'V/bIII': 'Eb', 'V/bVI': 'Ab', 
                      'bII': 'Gb', 'III': 'A', 'bIII': 'Ab', 'iv': 'Bbm', 'VI': 'D', 'bVI': 'Db', 'bVII': 'Eb'},
                 'F#' : {'I': 'F#', 'ii': 'G#m', 'iii': 'A#m', 'IV': 'B', 'V': 'C#', 'vi': 'D#m', 'vii': 'E#dim', 
                       'V/ii': 'D#', 'V/iii': 'E#', 'V/V': 'G#', 'V/vi': 'A#', 'V/bII': 'Dnat', 'V/bIII': 'Enat', 'V/bVI': 'Anat', 
                      'bII': 'Gnat', 'III': 'A#', 'bIII': 'Anat', 'iv': 'Bm', 'VI': 'D#', 'bVI': 'Dnat', 'bVII': 'Enat'},
                 'G' : {'I': 'G', 'ii': 'Am', 'iii': 'Bm', 'IV': 'C', 'V': 'D', 'vi': 'Em', 'vii': 'F#dim', 
                       'V/ii': 'E', 'V/iii': 'F#', 'V/V': 'A', 'V/vi': 'B', 'V/bII': 'Eb', 'V/bIII': 'F', 'V/bVI': 'Bb', 
                      'bII': 'Ab', 'III': 'B', 'bIII': 'Bb', 'iv': 'Cm', 'VI': 'E', 'bVI': 'Eb', 'bVII': 'F'},
                 'Ab' : {'I': 'Ab', 'ii': 'Bbm', 'iii': 'Cm', 'IV': 'Db', 'V': 'Eb', 'vi': 'Fm', 'vii': 'Gdim', 
                       'V/ii': 'F', 'V/iii': 'G', 'V/V': 'Bb', 'V/vi': 'C', 'V/bII': 'Enat', 'V/bIII': 'Gb', 'V/bVI': 'Bnat', 
                      'bII': 'Anat', 'III': 'C', 'bIII': 'Bnat', 'iv': 'Dbm', 'VI': 'F', 'bVI': 'Enat', 'bVII': 'Gb'},
                 'A' : {'I': 'A', 'ii': 'Bm', 'iii': 'C#m', 'IV': 'D', 'V': 'E', 'vi': 'F#m', 'vii': 'G#dim', 
                       'V/ii': 'F#', 'V/iii': 'G#', 'V/V': 'B', 'V/vi': 'C#', 'V/bII': 'Fnat', 'V/bIII': 'Gnat', 'V/bVI': 'Cnat', 
                      'bII': 'Bb', 'III': 'C#', 'bIII': 'Cnat', 'iv': 'Dm', 'VI': 'F#', 'bVI': 'Fnat', 'bVII': 'Gnat'},
                 'Bb' : {'I': 'Bb', 'ii': 'Cm', 'iii': 'Dm', 'IV': 'Eb', 'V': 'F', 'vi': 'Gm', 'vii': 'Adim', 
                       'V/ii': 'G', 'V/iii': 'A', 'V/V': 'C', 'V/vi': 'D', 'V/bII': 'Gb', 'V/bIII': 'Ab', 'V/bVI': 'Db', 
                      'bII': 'Bnat', 'III': 'D', 'bIII': 'Db', 'iv': 'Ebm', 'VI': 'G', 'bVI': 'Gb', 'bVII': 'Ab'},
                 'B' : {'I': 'B', 'ii': 'C#m', 'iii': 'D#m', 'IV': 'E', 'V': 'F#', 'vi': 'G#m', 'vii': 'A#dim', 
                       'V/ii': 'G#', 'V/iii': 'A#', 'V/V': 'C#', 'V/vi': 'D#', 'V/bII': 'Gnat', 'V/bIII': 'Anat', 'V/bVI': 'Dnat', 
                      'bII': 'Cnat', 'III': 'D#', 'bIII': 'Dnat', 'iv': 'Em', 'VI': 'G#', 'bVI': 'Gnat', 'bVII': 'Anat'}}

#This tells "playsound" which audio file to look for:
audio_list = {'C' : {'C': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c.wav', 'C7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'C7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'C9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'C11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'C9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'CM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj7.wav', 'CM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj9.wav', 'CM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj7b9.wav', 'CM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj11.wav', 'CM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj9#11.wav', 'Cm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin.wav', 'Cm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin7.wav', 'Cm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin9.wav', 'Cm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin7b9.wav', 'Cm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin11.wav', 'Cm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmin9#11.wav', 'Cnat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c.wav', 'CnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj7.wav', 'CnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj9.wav', 'CnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj7b9.wav', 'CnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj11.wav', 'CnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cmaj9#11.wav', 'Cnat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Cnat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Cnat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Cnat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Cnat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Cnatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/csus2.wav', 'Cnatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/csus4.wav', 'Cdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cdim.wav', 'Cdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/cdim7.wav', 'Csus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/csus2.wav', 'Csus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/csus4.wav', 'C#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db.wav', 'C#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db7.wav', 'C#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db7b9.wav', 'C#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db9.wav', 'C#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db11.wav', 'C#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db9#11.wav', 'C#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj7.wav', 'C#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj9.wav', 'C#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj7b9.wav', 'C#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj11.wav', 'C#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj9#11.wav', 'C#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin.wav', 'C#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin7.wav', 'C#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin9.wav', 'C#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin7b9.wav', 'C#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin11.wav', 'C#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin9#11.wav', 'C#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbsus2.wav', 'C#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbsus4.wav', 'C#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbdim.wav', 'C#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbdim7.wav', 'Cb': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b.wav', 'Cb7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b7.wav', 'Cb7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b7b9.wav', 'Cb9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b9.wav', 'Cb11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b11.wav', 'Cb9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b9#11.wav', 'CbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj7.wav', 'CbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9.wav', 'CbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj7b9.wav', 'CbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj11.wav', 'CbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9#11.wav', 'Cbm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin.wav', 'Cbm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin7.wav', 'Cbm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin9.wav', 'Cbm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin7b9.wav', 'Cbm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin11.wav', 'Cbm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin9#11.wav', 'Cbsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus2.wav', 'Cbsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus4.wav', 'Cbdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bdim.wav', 'Cbdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bdim7.wav'},
             'D'  : {'D': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d.wav', 'D7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d7.wav', 'D7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d7b9.wav', 'D9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d9.wav', 'D11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d11.wav', 'D9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d9#11.wav', 'DM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Dmaj7.wav', 'DM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj9.wav', 'DM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj7b9.wav', 'DM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Dmaj11.wav', 'DM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj9#11.wav', 'Dm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin.wav', 'Dm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin7.wav', 'Dm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin9.wav', 'Dm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin7b9.wav', 'Dm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin11.wav', 'Dm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmin9#11.wav', 'Dnat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/d.wav', 'DnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj7.wav', 'DnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj9.wav', 'DnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj7b9.wav', 'DnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj11.wav', 'DnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dmaj9#11.wav', 'Dnat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Dnat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Dnat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Dnat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Dnat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Dnatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dsus2.wav', 'Dnatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dsus4.wav', 'Ddim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ddim.wav', 'Ddim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ddim7.wav', 'Dsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dsus2.wav', 'Dsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dsus4.wav', 'D#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb.wav', 'D#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb7.wav', 'D#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb7b9.wav', 'D#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb9.wav', 'D#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb11.wav', 'D#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb9#11.wav', 'D#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj7.wav', 'D#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj9.wav', 'D#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj7b9.wav', 'D#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj11.wav', 'D#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj9#11.wav', 'D#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin.wav', 'D#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin7.wav', 'D#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin9.wav', 'D#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin7b9.wav', 'D#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin11.wav', 'D#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin9#11.wav', 'D#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebsus2.wav', 'D#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebsus4.wav', 'D#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebdim.wav', 'D#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebdim7.wav', 'Db': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db.wav', 'Db7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db7.wav', 'Db7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Db7b9.wav', 'Db9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db9.wav', 'Db11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db11.wav', 'Db9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/db9#11.wav', 'DbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj7.wav', 'DbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj9.wav', 'DbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj7b9.wav', 'DbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj11.wav', 'DbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmaj9#11.wav', 'Dbm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin.wav', 'Dbm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin7.wav', 'Dbm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin9.wav', 'Dbm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin7b9.wav', 'Dbm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin11.wav', 'Dbm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbmin9#11.wav', 'Dbsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbsus2.wav', 'Dbsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbsus4.wav', 'Dbdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbdim.wav', 'Dbdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/dbdim7.wav'},
             'E'  : {'E': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e.wav', 'E7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e7.wav', 'E7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e7b9.wav', 'E9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e9.wav', 'E11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e11.wav', 'E9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e9#11.wav', 'EM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Emaj7.wav', 'EM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9.wav', 'EM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj7b9.wav', 'EM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Emaj11.wav', 'EM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9#11.wav', 'Em': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin.wav', 'Em7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin7.wav', 'Em9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin9.wav', 'Em7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin7b9.wav', 'Em11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin11.wav', 'Em9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin9#11.wav', 'Enat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e.wav', 'EnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj7.wav', 'EnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9.wav', 'EnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj7b9.wav', 'EnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj11.wav', 'EnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9#11.wav', 'Enat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Enat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Enat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Enat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Enat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Enatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus2.wav', 'Enatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus4.wav', 'Edim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/edim.wav', 'Edim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/edim7.wav', 'Esus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus2.wav', 'Esus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus4.wav', 'E#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f.wav', 'E#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f7.wav', 'E#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f7b9.wav', 'E#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f9.wav', 'E#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f11.wav', 'E#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f9#11.wav', 'E#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj7.wav', 'E#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9.wav', 'E#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj7b9.wav', 'E#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj11.wav', 'E#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9#11.wav', 'E#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin.wav', 'E#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin7.wav', 'E#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin9.wav', 'E#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin7b9.wav', 'E#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin11.wav', 'E#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin9#11.wav', 'E#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus2.wav', 'E#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus4.wav', 'E#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fdim.wav', 'E#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fdim7.wav', 'Eb': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb.wav', 'Eb7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb7.wav', 'Eb7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Eb7b9.wav', 'Eb9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb9.wav', 'Eb11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb11.wav', 'Eb9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/eb9#11.wav', 'EbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj7.wav', 'EbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj9.wav', 'EbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj7b9.wav', 'EbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj11.wav', 'EbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmaj9#11.wav', 'Ebm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin.wav', 'Ebm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin7.wav', 'Ebm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin9.wav', 'Ebm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin7b9.wav', 'Ebm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin11.wav', 'Ebm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebmin9#11.wav', 'Ebsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebsus2.wav', 'Ebsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebsus4.wav', 'Ebdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebdim.wav', 'Ebdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ebdim7.wav'},
             'F'  : {'F': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f.wav', 'F7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f7.wav', 'F7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f7b9.wav', 'F9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f9.wav', 'F11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f11.wav', 'F9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f9#11.wav', 'FM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Fmaj7.wav', 'FM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9.wav', 'FM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj7b9.wav', 'FM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Fmaj11.wav', 'FM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9#11.wav', 'Fm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin.wav', 'Fm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin7.wav', 'Fm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin9.wav', 'Fm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin7b9.wav', 'Fm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin11.wav', 'Fm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmin9#11.wav', 'Fnat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f.wav', 'FnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj7.wav', 'FnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9.wav', 'FnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj7b9.wav', 'FnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj11.wav', 'FnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fmaj9#11.wav', 'Fnat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Fnat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Fnat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Fnat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Fnat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Fnatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus2.wav', 'Fnatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus4.wav', 'Fdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fdim.wav', 'Fdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fdim7.wav', 'Fsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus2.wav', 'Fsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/fsus4.wav', 'F#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#.wav', 'F#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#7.wav', 'F#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#7b9.wav', 'F#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#9.wav', 'F#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#11.wav', 'F#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#9#11.wav', 'F#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj7.wav', 'F#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj9.wav', 'F#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj7b9.wav', 'F#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj11.wav', 'F#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj9#11.wav', 'F#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min.wav', 'F#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min7.wav', 'F#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min9.wav', 'F#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min7b9.wav', 'F#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min11.wav', 'F#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min9#11.wav', 'F#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#sus2.wav', 'F#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#sus4.wav', 'F#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#dim.wav', 'F#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#dim7.wav', 'Fb': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e.wav', 'Fb7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e7.wav', 'Fb7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Fb7b9.wav', 'Fb9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e9.wav', 'Fb11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e11.wav', 'Fb9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/e9#11.wav', 'FbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj7.wav', 'FbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9.wav', 'FbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj7b9.wav', 'FbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj11.wav', 'FbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emaj9#11.wav', 'Fbm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin.wav', 'Fbm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin7.wav', 'Fbm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin9.wav', 'Fbm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin7b9.wav', 'Fbm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin11.wav', 'Fbm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/emin9#11.wav', 'Fbsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus2.wav', 'Fbsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/esus4.wav', 'Fbdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/edim.wav', 'Fbdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/edim7.wav'},
             'G'  : {'G': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g.wav', 'G7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g7.wav', 'G7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g7b9.wav', 'G9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g9.wav', 'G11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g11.wav', 'G9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g9#11.wav', 'GM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Gmaj7.wav', 'GM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj9.wav', 'GM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj7b9.wav', 'GM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Gmaj11.wav', 'GM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj9#11.wav', 'Gm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin.wav', 'Gm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin7.wav', 'Gm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin9.wav', 'Gm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin7b9.wav', 'Gm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin11.wav', 'Gm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmin9#11.wav', 'Gnat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/g.wav', 'GnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj7.wav', 'GnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj9.wav', 'GnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj7b9.wav', 'GnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj11.wav', 'GnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gmaj9#11.wav', 'Gnat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Gnat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Gnat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Gnat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Gnat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Gnatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gsus2.wav', 'Gnatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gsus4.wav', 'Gdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gdim.wav', 'Gdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gdim7.wav', 'Gsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gsus2.wav', 'Gsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/gsus4.wav', 'G#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab.wav', 'G#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab7.wav', 'G#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab7b9.wav', 'G#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab9.wav', 'G#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab11.wav', 'G#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab9#11.wav', 'G#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj7.wav', 'G#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj9.wav', 'G#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj7b9.wav', 'G#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj11.wav', 'G#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj9#11.wav', 'G#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin.wav', 'G#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin7.wav', 'G#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin9.wav', 'G#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin7b9.wav', 'G#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin11.wav', 'G#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin9#11.wav', 'G#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/absus2.wav', 'G#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/absus4.wav', 'G#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abdim.wav', 'G#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abdim7.wav', 'Gb': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#.wav', 'Gb7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#7.wav', 'Gb7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Gb7b9.wav', 'Gb9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#9.wav', 'Gb11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#11.wav', 'Gb9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#9#11.wav', 'GbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj7.wav', 'GbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj9.wav', 'GbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj7b9.wav', 'GbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj11.wav', 'GbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#maj9#11.wav', 'Gbm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min.wav', 'Gbm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min7.wav', 'Gbm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min9.wav', 'Gbm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min7b9.wav', 'Gbm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min11.wav', 'Gbm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#min9#11.wav', 'Gbsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#sus2.wav', 'Gbsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#sus4.wav', 'Gbdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#dim.wav', 'Gbdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/f#dim7.wav'},
             'A'  : {'A': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a.wav', 'A7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a7.wav', 'A7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a7b9.wav', 'A9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a9.wav', 'A11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a11.wav', 'A9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a9#11.wav', 'AM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Amaj7.wav', 'AM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj9.wav', 'AM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj7b9.wav', 'AM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Amaj11.wav', 'AM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj9#11.wav', 'Am': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin.wav', 'Am7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin7.wav', 'Am9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin9.wav', 'Am7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin7b9.wav', 'Am11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin11.wav', 'Am9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amin9#11.wav', 'Anat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/a.wav', 'AnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj7.wav', 'AnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj9.wav', 'AnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj7b9.wav', 'AnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj11.wav', 'AnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/amaj9#11.wav', 'Anat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Anat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Anat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Anat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Anat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Anatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/asus2.wav', 'Anatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/asus4.wav', 'Adim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/adim.wav', 'Adim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/adim7.wav', 'Asus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/asus2.wav', 'Asus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/asus4.wav', 'A#': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb.wav', 'A#7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb7.wav', 'A#7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb7b9.wav', 'A#9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb9.wav', 'A#11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb11.wav', 'A#9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb9#11.wav', 'A#M7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj7.wav', 'A#M9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj9.wav', 'A#M7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj7b9.wav', 'A#M11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj11.wav', 'A#M9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj9#11.wav', 'A#m': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin.wav', 'A#m7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin7.wav', 'A#m9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin9.wav', 'A#m7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin7b9.wav', 'A#m11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin11.wav', 'A#m9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin9#11.wav', 'A#sus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbsus2.wav', 'A#sus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbsus4.wav', 'A#dim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbdim.wav', 'A#dim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbdim7.wav', 'Ab': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab.wav', 'Ab7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab7.wav', 'Ab7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Ab7b9.wav', 'Ab9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab9.wav', 'Ab11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab11.wav', 'Ab9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/ab9#11.wav', 'AbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj7.wav', 'AbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj9.wav', 'AbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj7b9.wav', 'AbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj11.wav', 'AbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmaj9#11.wav', 'Abm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin.wav', 'Abm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin7.wav', 'Abm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin9.wav', 'Abm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin7b9.wav', 'Abm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin11.wav', 'Abm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abmin9#11.wav', 'Absus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/absus2.wav', 'Absus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/absus4.wav', 'Abdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abdim.wav', 'Abdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/abdim7.wav'},
             'B'  : {'B': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b.wav', 'B7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b7.wav', 'B7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b7b9.wav', 'B9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b9.wav', 'B11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b11.wav', 'B9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b9#11.wav', 'BM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Bmaj7.wav', 'BM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9.wav', 'BM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj7b9.wav', 'BM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Bmaj11.wav', 'BM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9#11.wav', 'Bm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin.wav', 'Bm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin7.wav', 'Bm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin9.wav', 'Bm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin7b9.wav', 'Bm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin11.wav', 'Bm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmin9#11.wav', 'Bnat': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/b.wav', 'BnatM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj7.wav', 'BnatM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9.wav', 'BnatM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj7b9.wav', 'BnatM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj11.wav', 'BnatM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bmaj9#11.wav', 'Bnat7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7.wav', 'Bnat9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9.wav', 'Bnat7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c7b9.wav', 'Bnat11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c11.wav', 'Bnat9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/c9#11.wav', 'Bnatsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus2.wav', 'Bnatsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus4.wav', 'Bdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bdim.wav', 'Bdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bdim7.wav', 'Bsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus2.wav', 'Bsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bsus4.wav', 'Bb': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb.wav', 'Bb7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb7.wav', 'Bb7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/Bb7b9.wav', 'Bb9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb9.wav', 'Bb11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb11.wav', 'Bb9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bb9#11.wav', 'BbM7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj7.wav', 'BbM9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj9.wav', 'BbM7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj7b9.wav', 'BbM11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj11.wav', 'BbM9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmaj9#11.wav', 'Bbm': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin.wav', 'Bbm7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin7.wav', 'Bbm9': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin9.wav', 'Bbm7(b9)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin7b9.wav', 'Bbm11': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin11.wav', 'Bbm9(#11)': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbmin9#11.wav', 'Bbsus2': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbsus2.wav', 'Bbsus4': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbsus4.wav', 'Bbdim': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbdim.wav', 'Bbdim7': 'C:/Users/ellog/Desktop/Music stuff/Chord generator recordings/bbdim7.wav'}}

#Used for picking a random key:
short_key_list = ['C', 'Db', 'D', 'Eb', 'E', 'F', 'F#', 'G', 'Ab', 'A', 'Bb', 'B']

#Defining a function used to narrow down our audio file search:
def first1(string):
    return string[:1]

#Pre-setting some assorted keys:
is_finished = -1
seventh_chance = 0
chromatic_choice = -1
key_choice = -1
random_choice = -1
numeral = 0

#Here is where the user begins interacting with the code.
#First, the user is prompted to pick either a chromatic or diatonic chord progression:
chromatic_option = input('Pick an option: chromatic or diatonic? ')
while chromatic_choice == -1:
    if chromatic_option.lower() == 'chromatic':
        chromatic_choice = 1
        numeral = Ic
        modality_option = 'major'
    elif chromatic_option.lower() == 'diatonic':
        chromatic_choice = 0
    else:
        chromatic_option = input('I didn\'t understand your answer. Please pick again: chromatic or diatonic? ')

#The user is asked whether they would like lead-sheet symbols, or just Roman Numerals:
key_option = input('Would you like to chords to be given a specific key? Yes or no: ')
while key_choice == -1:
    if key_option.lower() == 'yes':
        key_choice = 1
    elif key_option.lower() == 'no':
        key_choice = 0
        overall_key = short_key_list[randint(0, 12)]
    else: key_option = input('I didn\'t understand your answer. Please pick again: yes or no? ')

#Next, you tell the generator whether you would like to pick your own key, or have one randomly selected:
if key_choice == 1:
    random_key_option = input('Would you like to select your own key? Yes or no: ')
    while random_choice == -1:
        if random_key_option.lower() == 'yes':
            random_choice = 1
        elif random_key_option.lower() == 'no':
            random_choice = 0
            overall_key = short_key_list[randint(0, 12)]
        else:
            random_key_option = input('I didn\'t understand your answer. Please pick again: yes or no? ')

#If you're picking your own key, this is where you do that:
if key_choice == 1 and random_choice == 1:
    key_select = input('Type the letter name of your chosen key. Options: C, Db, D, Eb, E, F, F#, G, Ab, A, Bb, B. ')
    while random_choice == 1:
        if key_select == 'C' or key_select == 'Db' or key_select == 'D' or key_select == 'Eb' or key_select == 'E' or key_select == 'F' or key_select == 'F#' or key_select == 'G' or key_select == 'Ab' or key_select == 'A' or key_select == 'Bb' or key_select == 'B':
            overall_key = key_select
            random_choice = 2
        else:
            key_select = input('I didn\'t understand your answer. Options: C, Db, D, Eb, E, F, F#, G, Ab, A, Bb, B. ')

#If you picked a diatonic progression, here you select major or minor and whether or not you want seventh chords:
if chromatic_choice == 0:
    modality_option = input('Pick an option: major or minor? ')
    while numeral == 0:
        if modality_option.lower() == 'major':
            numeral = I
            lead_sheet_list = major_key_list[overall_key]
        elif modality_option.lower() == 'minor':
            numeral = i
            lead_sheet_list = minor_key_list[overall_key]
        else:
            modality_option = input('I didn\'t understand your answer. Please pick again: major or minor? ')
    seventh_option = input('Seventh chords: yes or no? ')
    while seventh_chance != 1:
        if seventh_option.lower() == 'yes':
            seventh_chords = True
            seventh_chance = 1
        elif seventh_option.lower() == 'no':
            seventh_chords = False
            seventh_chance = 1
        else:
            seventh_option = input('I didn\'t understand your answer. Please pick again: yes or no? ')
else:
    lead_sheet_list = chrom_key_list[overall_key]

#Finally, you're allowed to manipulate the length of the progression you're given:
length_option = input('Pick an option: short or long? ')
while is_finished == -1:
    if length_option.lower() == 'short':
        is_finished = 1
    elif length_option.lower() == 'long':
        is_finished = 0
    else:
        length_option = input('I didn\'t understand your answer. Please pick again: short or long? ')
            
print('')

#Here we go! From here on out, there are no more user inputs. The generator starts by printing the "tonic" chord
#of the key we're in and playing the associated audio file:
if key_choice == 1:
    if modality_option.lower() == 'minor':
        print('Your key:', overall_key, 'minor')
        print('{:-<15}'.format('i'), overall_key +'m')
        playsound(audio_list[first1(overall_key)][overall_key + 'm'])
    else:
        print('Your key:', overall_key, 'major')
        print('{:-<15}'.format('I'), overall_key)
        playsound(audio_list[first1(overall_key)][overall_key])
else:
    if modality_option.lower() == 'minor':
        print('i')
    else:
        print('I')

#Now we enter the main "loop" of the program. We will cycle through this loop multiple times, generating a new
#random number for each iteration that determines the chord of the next cycle. The various lines of code tell
#the generator what text to print as a result of the chosen chord as well as which audio file to search for.
#This section is very long and unnecessarily complicated because many of the chromatic chord options require
#additional text extensions to be placed in the middle of an existing string, and I couldn't be bothered to
#change the way it worked until I was nearly finished making it. In the end, this MASSIVELY backfired and resulted
#in a far greater time sink than I'd hoped for, but at least it still works.
if chromatic_choice == 1:
    while is_finished != 2:
        numeral_index = randint(0, len(numeral))
        numeral_choice = numeral[numeral_index]
        extension = randint(0, 12)
        if key_choice == 1:
            if numeral_choice == 'V/ii':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/ii'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] +'7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/ii'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/ii'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/ii'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/ii'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/iii':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/iii'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/iii'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/iii'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/iii'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/iii'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/V':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/V'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/V'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/V'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/V'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/V'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '9(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/vi':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/vi'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/vi'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/vi'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/vi'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/vi'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '9(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/bII':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/bII'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/bII'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/bII'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/bII'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/bII'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '9(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/bIII':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/bIII'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/bIII'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/bIII'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '9(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/bIII'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/bIII'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '9(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            elif numeral_choice == 'V/bVI':
                if extension == 3 or extension == 4:
                    print('{:-<15}'.format('V7/bVI'), lead_sheet_list[numeral_choice] + '7')
                    sound = lead_sheet_list[numeral_choice] + '7'
                elif extension == 5:
                    print('{:-<15}'.format('V9/bVI'), lead_sheet_list[numeral_choice] + '9')
                    sound = lead_sheet_list[numeral_choice] + '9'
                elif extension == 7:
                    print('{:-<15}'.format('V7(b9)/bVI'), lead_sheet_list[numeral_choice] + '7(b9)')
                    sound = lead_sheet_list[numeral_choice] + '7(b9)'
                elif extension == 8:
                    print('{:-<15}'.format('V11/bVI'), lead_sheet_list[numeral_choice] + '11')
                    sound = lead_sheet_list[numeral_choice] + '11'
                elif extension == 9:
                    print('{:-<15}'.format('V9(#11)/bVI'), lead_sheet_list[numeral_choice] + '9(#11)')
                    sound = lead_sheet_list[numeral_choice] + '9(#11)'
                else:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                    sound = lead_sheet_list[numeral_choice]
            else:
                if 'dim' in lead_sheet_list[numeral_choice]:
                    if extension <= 8:
                        print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                        sound = lead_sheet_list[numeral_choice]
                    else:
                        print('{:-<15}'.format(numeral_choice + '7'), lead_sheet_list[numeral_choice] + '7')
                        sound = lead_sheet_list[numeral_choice] + '7'
                else:
                    if extension <= 2:
                        print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                        sound = lead_sheet_list[numeral_choice]
                    elif extension == 3 or extension == 4:
                        if 'V' in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '7'), lead_sheet_list[numeral_choice] + '7')
                            sound = lead_sheet_list[numeral_choice] + '7'
                        elif 'i'.lower() in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '7'), lead_sheet_list[numeral_choice] + '7')
                            sound = lead_sheet_list[numeral_choice] + '7'
                        else:
                            print('{:-<15}'.format(numeral_choice + 'M7'), lead_sheet_list[numeral_choice] + 'M7')
                            sound = lead_sheet_list[numeral_choice] + 'M7'
                    elif extension == 5:
                        if 'V' in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '9'), lead_sheet_list[numeral_choice] + '9')
                            sound = lead_sheet_list[numeral_choice] + '9'
                        elif 'i'.lower() in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '9'), lead_sheet_list[numeral_choice] + '9')
                            sound = lead_sheet_list[numeral_choice] + '9'
                        else:
                            print('{:-<15}'.format(numeral_choice + 'M9'), lead_sheet_list[numeral_choice] + 'M9')
                            sound = lead_sheet_list[numeral_choice] + 'M9'
                    elif extension == 6:
                        print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                        sound = lead_sheet_list[numeral_choice]
                    elif extension == 7:
                        if 'V' in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '7(b9)'), lead_sheet_list[numeral_choice] + '7(b9)')
                            sound = lead_sheet_list[numeral_choice] + '7(b9)'
                        elif 'i'.lower() in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '7(b9)'), lead_sheet_list[numeral_choice] + '7(b9)')
                            sound = lead_sheet_list[numeral_choice] + '7(b9)'
                        else:
                            print('{:-<15}'.format(numeral_choice + 'M7(b9)'), lead_sheet_list[numeral_choice] + 'M7(b9)')
                            sound = lead_sheet_list[numeral_choice] + 'M7(b9)'
                    elif extension == 8:
                        if 'V' in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '11'), lead_sheet_list[numeral_choice] + '11')
                            sound = lead_sheet_list[numeral_choice] + '11'
                        elif 'i'.lower() in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '11'), lead_sheet_list[numeral_choice] + '11')
                            sound = lead_sheet_list[numeral_choice] + '11'
                        else:
                            print('{:-<15}'.format(numeral_choice + 'M11'), lead_sheet_list[numeral_choice] + 'M11')
                            sound = lead_sheet_list[numeral_choice] + 'M11'
                    elif extension == 9:
                        if 'V' in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '9(#11)'), lead_sheet_list[numeral_choice] + '9(#11)')
                            sound = lead_sheet_list[numeral_choice] + '9(#11)'
                        elif 'i'.lower() in numeral_choice:
                            print('{:-<15}'.format(numeral_choice + '9(#11)'), lead_sheet_list[numeral_choice] + '9(#11)')
                            sound = lead_sheet_list[numeral_choice] + '9(#11)'
                        else:
                            print('{:-<15}'.format(numeral_choice + 'M9(#11)'), lead_sheet_list[numeral_choice] + 'M9(#11)')
                            sound = lead_sheet_list[numeral_choice] + 'M9(#11)'
                    elif extension == 10:
                        if 'm' in lead_sheet_list[numeral_choice]:
                            print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                            sound = lead_sheet_list[numeral_choice]
                        else:
                            print('{:-<15}'.format(numeral_choice + 'sus2'), lead_sheet_list[numeral_choice] + 'sus2')
                            sound = lead_sheet_list[numeral_choice] + 'sus2'
                    elif extension == 11:
                        if 'm' in lead_sheet_list[numeral_choice]:
                            print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                            sound = lead_sheet_list[numeral_choice]
                        else:
                            print('{:-<15}'.format(numeral_choice + 'sus4'), lead_sheet_list[numeral_choice] + 'sus4')
                            sound = lead_sheet_list[numeral_choice] + 'sus4'
            playsound(audio_list[first1(lead_sheet_list[numeral_choice])][sound])
        else:
            if numeral_choice == 'V/ii':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/ii')
                elif extension == 5:
                    print('V9/ii')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/ii')
                elif extension == 8:
                    print('V11/ii')
                elif extension == 9:
                    print('V9(#11)/ii')
            elif numeral_choice == 'V/iii':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/iii')
                elif extension == 5:
                    print('V9/iii')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/iii')
                elif extension == 8:
                    print('V11/iii')
                elif extension == 9:
                    print('V9(#11)/iii')
            elif numeral_choice == 'V/V':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/V')
                elif extension == 5:
                    print('V9/V')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/V')
                elif extension == 8:
                    print('V11/V')
                elif extension == 9:
                    print('V9(#11)/V')
            elif numeral_choice == 'V/vi':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/vi')
                elif extension == 5:
                    print('V9/vi')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/vi')
                elif extension == 8:
                    print('V11/vi')
                elif extension == 9:
                    print('V9(#11)/vi')
            elif numeral_choice == 'V/bII':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/bII')
                elif extension == 5:
                    print('V9/bII')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/bII')
                elif extension == 8:
                    print('V11/bII')
                elif extension == 9:
                    print('V9(#11)/bII')
            elif numeral_choice == 'V/bIII':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/bIII')
                elif extension == 5:
                    print('V9/bIII')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/bIII')
                elif extension == 8:
                    print('V11/bIII')
                elif extension == 9:
                    print('V9(#11)/bIII')
            elif numeral_choice == 'V/bVI':
                if extension <= 2:
                    print(numeral_choice)
                elif extension == 3 or extension == 4:
                    print('V7/bVI')
                elif extension == 5:
                    print('V9/bVI')
                elif extension == 6:
                    print(numeral_choice)
                elif extension == 7:
                    print('V7(b9)/bVI')
                elif extension == 8:
                    print('V11/bVI')
                elif extension == 9:
                    print('V9(#11)/bVI')
            else:
                if 'dim' in lead_sheet_list[numeral_choice]:
                    if extension <= 8:
                        print(numeral_choice)
                    else:
                        print(numeral_choice)
                else:
                    if extension <= 2:
                        print(numeral_choice)
                    elif extension == 3 or extension == 4:
                        if 'V' in numeral_choice:
                            print(numeral_choice + '7')
                        elif 'i'.lower() in numeral_choice:
                            print(numeral_choice + '7')
                        else:
                            print(numeral_choice + 'M7')
                    elif extension == 5:
                        if 'V' in numeral_choice:
                            print(numeral_choice + '9')
                        elif 'i'.lower() in numeral_choice:
                            print(numeral_choice + '9')
                        else:
                            print(numeral_choice + 'M9')
                    elif extension == 6:
                        print(numeral_choice)
                    elif extension == 7:
                        if 'V' in numeral_choice:
                            print(numeral_choice + '7(b9)')
                        elif 'i'.lower() in numeral_choice:
                            print(numeral_choice + '7(b9)')
                        else:
                            print(numeral_choice + 'M7(b9)')
                    elif extension == 8:
                        if 'V' in numeral_choice:
                            print(numeral_choice + '11')
                        elif 'i'.lower() in numeral_choice:
                            print(numeral_choice + '11')
                        else:
                            print(numeral_choice + 'M11')
                    elif extension == 9:
                        if 'V' in numeral_choice:
                            print(numeral_choice + '9(#11)')
                        elif 'i'.lower() in numeral_choice:
                            print(numeral_choice + '9(#11)')
                        else:
                            print(numeral_choice + 'M9(#11)')
                    elif extension == 10:
                        print(numeral_choice + 'sus2')
                    elif extension == 11:
                        print(numeral_choice + 'sus4')
        if numeral_choice == 'I':
            is_finished += 1
        numeral = chrom_numeral_list[numeral_choice]

#This very last section is the diatonic chord generator. It's incomplete at the moment, but wouldn't take long
#to update to give it the same capabilities as the chromatic chord generator.
else:
    while is_finished != 2:
        numeral_index = randint(0, len(numeral))
        numeral_choice = numeral[numeral_index]
        if seventh_chords == True:
            seventh_chance = randint(0, 3)
            if seventh_chance == 2:
                if key_choice == 1:
                    print('{:-<15}'.format(numeral_choice + '7'), lead_sheet_list[numeral_choice] + '7')
                else:
                    print(numeral_choice + '7')
            else:
                if key_choice == 1:
                    print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
                else:
                    print(numeral_choice)
        else:
            if key_choice == 1:
                print('{:-<15}'.format(numeral_choice), lead_sheet_list[numeral_choice])
            else:
                print(numeral_choice)
        if numeral_choice == 'I' or numeral_choice == 'i':
            is_finished += 1
        if modality_option.lower() == 'major':
            numeral = major_numeral_list[numeral_choice]
        else:
            numeral = minor_numeral_list[numeral_choice]
# Out:
# Pick an option: chromatic or diatonic? chromatic
# Would you like to chords to be given a specific key? Yes or no: yes
# Would you like to select your own key? Yes or no: yes
# Type the letter name of your chosen key. Options: C, Db, D, Eb, E, F, F#, G, Ab, A, Bb, B. F
# Pick an option: short or long? long
#
# Your key: F major
# I-------------- F
# V/bII---------- Db
# bIIM11--------- GbM11
# vii------------ Edim
# I-------------- F
# IIIsus4-------- Asus4
# bIII----------- Ab
# vi------------- Dm
# bIIM7---------- GbM7
# V7(b9)--------- C7(b9)
# IM11----------- FM11
